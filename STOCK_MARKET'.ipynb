# %%
from nselib import capital_market as cap

# %%
import pandas as pd
import datetime as dt
from nselib.libutil import *
from nselib.constants import *

# %%
cap.price_volume_and_deliverable_position_data('SBIN',period='1M')
# Out:
#    Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0     NaN     EQ  01-Jan-2024     642.05     642.20     646.90    638.00
# 1     NaN     EQ  02-Jan-2024     641.35     641.35     648.00    633.85
# 2     NaN     EQ  03-Jan-2024     639.45     639.35     648.00    635.80
# 3     NaN     EQ  04-Jan-2024     643.45     642.50     646.40    638.65
# 4     NaN     EQ  05-Jan-2024     642.75     645.00     651.75    637.75
# 5     NaN     EQ  08-Jan-2024     641.95     640.00     645.00    625.05
# 6     NaN     EQ  09-Jan-2024     627.00     632.00     634.35    624.50
# 7     NaN     EQ  10-Jan-2024     625.40     624.80     625.30    618.20
# 8     NaN     EQ  11-Jan-2024     621.75     626.00     627.15    618.50
# 9     NaN     EQ  12-Jan-2024     620.20     623.80     636.50    621.10
# 10    NaN     EQ  15-Jan-2024     633.60     638.90     645.50    636.10
# 11    NaN     EQ  16-Jan-2024     640.10     640.00     644.90    633.45
# ...
